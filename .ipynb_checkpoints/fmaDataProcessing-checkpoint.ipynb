# %%
import os
# Directories creation for GTZAN
genres = 'electronic experimental folk hiphop instrumental international pop rock'
genres = genres.split()
for g in genres:
  path_audio = os.path.join('Datasets/fma/small_dataset_reduced_10s/',f'{g}')
  os.makedirs(path_audio)

# %%
import pydub
import soundfile as sf
from Datasets.fma.fma import utils

"""
Fma dataset reading
"""

tracks = utils.load('Datasets/fma/fma/data/fma_metadata/tracks.csv')
features = utils.load('Datasets/fma/fma/data/fma_metadata/features.csv')
small = tracks['set', 'subset'] <= 'small'

electronic = tracks['track', 'genre_top'] == 'Instrumental'
electronic_ids = tracks.loc[small & electronic, ('track', 'genre_top')].keys().tolist()

experimental = tracks['track', 'genre_top'] == 'Experimental'
experimental_ids = tracks.loc[small & experimental, ('track', 'genre_top')].keys().tolist()
experimental_ids.remove(133297) # Removing corrupted audio

folk = tracks['track', 'genre_top'] == 'Folk'
folk_ids = tracks.loc[small & folk, ('track', 'genre_top')].keys().tolist()

hiphop = tracks['track', 'genre_top'] == 'Hip-Hop'
hiphop_ids = tracks.loc[small & hiphop, ('track', 'genre_top')].keys().tolist()

instrumental = tracks['track', 'genre_top'] == 'Instrumental'
instrumental_ids = tracks.loc[small & instrumental, ('track', 'genre_top')].keys().tolist()

international = tracks['track', 'genre_top'] == 'Instrumental'
international_ids = tracks.loc[small & international, ('track', 'genre_top')].keys().tolist()

pop = tracks['track', 'genre_top'] == 'Pop'
pop_ids = tracks.loc[small & pop, ('track', 'genre_top')].keys().tolist()

rock = tracks['track', 'genre_top'] == 'Rock'
rock_ids = tracks.loc[small & rock, ('track', 'genre_top')].keys().tolist()
rock_ids.remove(108925) # Removing corrupted audio

# %%
import os

AUDIO_DIR = 'Datasets\\fma\\fma\\data\\fma_small\\'

def read_fma_audio(AUDIO_DIR, track_id):
    filename = AUDIO_DIR + str(track_id).zfill(6) + '.mp3'

    data = sf.read(filename)
    
    return data
    
#     return librosa.load(filename, sr=None, mono=True)

def get_fma_audio_name(AUDIO_DIR, track_id):
    return AUDIO_DIR + str(track_id).zfill(6) + '.mp3'

def cut_fma_audio(AUDIO_DIR, track_id, genre, segment_duration):
    file_name = get_fma_audio_name(AUDIO_DIR, track_id)
    t1 = 1*1000
    t2 = segment_duration*1000
    audio = pydub.AudioSegment.from_file(file_name)
    
    new_audio = audio[t1:t2]
    print(new_audio)
    new_file_name = file_name.split('\\')[-1].split('.')[0]
    print(new_file_name)
    song_out  =  os.path.join(r"C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced_10s", f'{genre}', f'{new_file_name}')
    print(song_out)
    new_audio.export(song_out, format="wav")
    return new_audio

audios_electronic = [
    cut_fma_audio(AUDIO_DIR, track_id, 'electronic', 10)[0] for track_id in electronic_ids
]
    
audios_experimental = [
    cut_fma_audio(AUDIO_DIR, track_id, 'experimental', 10)[0] for track_id in experimental_ids
] 

audios_folk = [
    cut_fma_audio(AUDIO_DIR, track_id, 'folk', 10)[0] for track_id in folk_ids
]

audios_hiphop = [
    cut_fma_audio(AUDIO_DIR, track_id, 'hiphop', 10)[0] for track_id in hiphop_ids
] 
    
audios_instrumental = [
    cut_fma_audio(AUDIO_DIR, track_id, 'instrumental', 10)[0] for track_id in instrumental_ids
]

audios_international = [
    cut_fma_audio(AUDIO_DIR, track_id, 'international', 10)[0] for track_id in international_ids
] 

audios_pop = [
    cut_fma_audio(AUDIO_DIR, track_id, 'pop', 10)[0] for track_id in pop_ids
] 

audios_rock = [
    cut_fma_audio(AUDIO_DIR, track_id, 'rock', 10)[0] for track_id in rock_ids
]
# Out:
# <pydub.audio_segment.AudioSegment object at 0x00000236FEA89108>
# 010250
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\010250
# <pydub.audio_segment.AudioSegment object at 0x00000236FEA89108>
# 011638
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\011638
# <pydub.audio_segment.AudioSegment object at 0x0000023686871388>
# 014568
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014568
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB034C8>
# 014569
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014569
# <pydub.audio_segment.AudioSegment object at 0x000002368B761988>
# 014570
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014570
# <pydub.audio_segment.AudioSegment object at 0x000002368B761908>
# 014571
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014571
# <pydub.audio_segment.AudioSegment object at 0x000002368B761608>
# 014572
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014572
# <pydub.audio_segment.AudioSegment object at 0x000002368B761608>
# 014576
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014576
# <pydub.audio_segment.AudioSegment object at 0x000002368B761908>
# 014577
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014577
# <pydub.audio_segment.AudioSegment object at 0x000002368B761608>
# 014578
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014578
# <pydub.audio_segment.AudioSegment object at 0x00000236868A28C8>
# 014579
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014579
# <pydub.audio_segment.AudioSegment object at 0x00000236868A28C8>
# 014580
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014580
# <pydub.audio_segment.AudioSegment object at 0x00000236868A28C8>
# 014581
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014581
# <pydub.audio_segment.AudioSegment object at 0x00000236817AF388>
# 014583
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014583
# <pydub.audio_segment.AudioSegment object at 0x000002368B761988>
# 014584
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014584
# <pydub.audio_segment.AudioSegment object at 0x00000236868A2088>
# 014585
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014585
# <pydub.audio_segment.AudioSegment object at 0x00000236868A2088>
# 014586
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014586
# <pydub.audio_segment.AudioSegment object at 0x00000236868A2088>
# 014588
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014588
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB45048>
# 014589
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014589
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB45048>
# 014590
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\014590
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB45048>
# 020361
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020361
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB45048>
# 020362
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020362
# <pydub.audio_segment.AudioSegment object at 0x000002368687B908>
# 020364
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020364
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20AC8>
# 020365
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020365
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20988>
# 020366
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020366
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20388>
# 020369
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020369
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB45608>
# 020372
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020372
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20A48>
# 020373
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020373
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20C88>
# 020374
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020374
# <pydub.audio_segment.AudioSegment object at 0x0000023681C205C8>
# 020375
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020375
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB45048>
# 020376
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\020376
# <pydub.audio_segment.AudioSegment object at 0x0000023681C209C8>
# 030196
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\030196
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20688>
# 037111
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\037111
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20688>
# 037113
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\037113
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB45048>
# 037119
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\037119
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20988>
# 037141
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\037141
# <pydub.audio_segment.AudioSegment object at 0x000002368687B588>
# 037911
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\037911
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20B48>
# 040250
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\040250
# <pydub.audio_segment.AudioSegment object at 0x000002368687B408>
# 040654
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\040654
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20308>
# 040655
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\040655
# <pydub.audio_segment.AudioSegment object at 0x000002368687B488>
# 040656
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\040656
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20D88>
# 040657
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\040657
# <pydub.audio_segment.AudioSegment object at 0x000002368687B108>
# 040658
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\040658
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20308>
# 040659
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\040659
# <pydub.audio_segment.AudioSegment object at 0x000002368687B908>
# 040660
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\040660
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20608>
# 041573
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\041573
# <pydub.audio_segment.AudioSegment object at 0x000002368687BD88>
# 041971
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\041971
# <pydub.audio_segment.AudioSegment object at 0x0000023681C202C8>
# 041983
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\041983
# <pydub.audio_segment.AudioSegment object at 0x000002368687B208>
# 045387
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\045387
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20608>
# 045388
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\045388
# <pydub.audio_segment.AudioSegment object at 0x000002368687B848>
# 045389
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\045389
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7AC8>
# 045390
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\045390
# <pydub.audio_segment.AudioSegment object at 0x000002368687BB08>
# 045391
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\045391
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7508>
# 045392
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\045392
# <pydub.audio_segment.AudioSegment object at 0x000002368687B588>
# 045393
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\045393
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7288>
# 046525
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\046525
# <pydub.audio_segment.AudioSegment object at 0x0000023681C209C8>
# 050955
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\050955
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20608>
# 050956
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\050956
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7288>
# 051776
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\051776
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20688>
# 052446
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\052446
# <pydub.audio_segment.AudioSegment object at 0x00000236838A78C8>
# 052447
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\052447
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20E88>
# 052448
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\052448
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7708>
# 052449
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\052449
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20B48>
# 052451
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\052451
# <pydub.audio_segment.AudioSegment object at 0x00000236838A71C8>
# 052452
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\052452
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20DC8>
# 054149
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054149
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7B88>
# 054150
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054150
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20DC8>
# 054151
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054151
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20DC8>
# 054152
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054152
# <pydub.audio_segment.AudioSegment object at 0x000002368687B548>
# 054153
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054153
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7148>
# 054154
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054154
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20DC8>
# 054155
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054155
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7608>
# 054156
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054156
# <pydub.audio_segment.AudioSegment object at 0x000002368687B788>
# 054158
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054158
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7348>
# 054159
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054159
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20DC8>
# 054160
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\054160
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7148>
# 057371
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\057371
# <pydub.audio_segment.AudioSegment object at 0x000002368687B508>
# 057418
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\057418
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7888>
# 062003
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\062003
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20B48>
# 062005
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\062005
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7A48>
# 062007
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\062007
# <pydub.audio_segment.AudioSegment object at 0x000002368687B808>
# 062180
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\062180
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7B88>
# 063287
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\063287
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20B48>
# 063289
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\063289
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7A08>
# 063290
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\063290
# <pydub.audio_segment.AudioSegment object at 0x000002368687B148>
# 063291
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\063291
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7888>
# 063292
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\063292
# <pydub.audio_segment.AudioSegment object at 0x0000023681C20B48>
# 066525
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\066525
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7F48>
# 066757
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\066757
# <pydub.audio_segment.AudioSegment object at 0x000002368687B488>
# 073495
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\073495
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7248>
# 075429
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075429
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB089C8>
# 075430
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075430
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB60588>
# 075431
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075431
# <pydub.audio_segment.AudioSegment object at 0x00000236838D3488>
# 075432
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075432
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB089C8>
# 075433
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075433
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB089C8>
# 075434
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075434
# <pydub.audio_segment.AudioSegment object at 0x00000236838C1D08>
# 075435
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075435
# <pydub.audio_segment.AudioSegment object at 0x00000236838C1D08>
# 075436
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075436
# <pydub.audio_segment.AudioSegment object at 0x000002368688D388>
# 075437
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075437
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54288>
# 075438
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075438
# <pydub.audio_segment.AudioSegment object at 0x000002368687BE08>
# 075439
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075439
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54048>
# 075440
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075440
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54288>
# 075441
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075441
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB541C8>
# 075442
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075442
# <pydub.audio_segment.AudioSegment object at 0x000002368687B908>
# 075443
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075443
# <pydub.audio_segment.AudioSegment object at 0x00000236838A77C8>
# 075607
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075607
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54288>
# 075612
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\075612
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB543C8>
# 076363
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\076363
# <pydub.audio_segment.AudioSegment object at 0x000002368687BD08>
# 080389
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\080389
# <pydub.audio_segment.AudioSegment object at 0x00000236838A71C8>
# 080402
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\080402
# <pydub.audio_segment.AudioSegment object at 0x000002368687B748>
# 080515
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\080515
# <pydub.audio_segment.AudioSegment object at 0x00000236838A79C8>
# 080516
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\080516
# <pydub.audio_segment.AudioSegment object at 0x000002368687B848>
# 080517
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\080517
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7AC8>
# 080518
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\080518
# <pydub.audio_segment.AudioSegment object at 0x000002368687B908>
# 080519
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\080519
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7448>
# 080520
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\080520
# <pydub.audio_segment.AudioSegment object at 0x000002368687B908>
# 081436
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081436
# <pydub.audio_segment.AudioSegment object at 0x000002368687BCC8>
# 081457
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081457
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54388>
# 081485
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081485
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB541C8>
# 081491
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081491
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7E88>
# 081512
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081512
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54288>
# 081523
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081523
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7388>
# 081543
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081543
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54288>
# 081554
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081554
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7D88>
# 081555
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081555
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB542C8>
# 081565
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081565
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7D08>
# 081576
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081576
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB544C8>
# 081586
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081586
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7D48>
# 081600
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081600
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB544C8>
# 081612
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081612
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB544C8>
# 081613
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081613
# <pydub.audio_segment.AudioSegment object at 0x000002368687BB48>
# 081623
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081623
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7E48>
# 081638
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081638
# <pydub.audio_segment.AudioSegment object at 0x000002368687B3C8>
# 081650
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081650
# <pydub.audio_segment.AudioSegment object at 0x000002368687B908>
# 081660
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081660
# <pydub.audio_segment.AudioSegment object at 0x000002368687B208>
# 081781
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081781
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54288>
# 081782
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081782
# <pydub.audio_segment.AudioSegment object at 0x000002368687BC88>
# 081792
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081792
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7148>
# 081802
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081802
# <pydub.audio_segment.AudioSegment object at 0x000002368687B748>
# 081803
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081803
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE788>
# 081814
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081814
# <pydub.audio_segment.AudioSegment object at 0x000002368687BC88>
# 081988
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081988
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB544C8>
# 081999
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\081999
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7C88>
# 082157
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082157
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE648>
# 082914
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082914
# <pydub.audio_segment.AudioSegment object at 0x000002368687BCC8>
# 082915
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082915
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB542C8>
# 082916
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082916
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7348>
# 082917
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082917
# <pydub.audio_segment.AudioSegment object at 0x000002368687B488>
# 082918
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082918
# <pydub.audio_segment.AudioSegment object at 0x000002368687BEC8>
# 082919
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082919
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEFC8>
# 082920
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082920
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB542C8>
# 082921
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082921
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB544C8>
# 082928
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082928
# <pydub.audio_segment.AudioSegment object at 0x000002368687B748>
# 082929
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082929
# <pydub.audio_segment.AudioSegment object at 0x000002368687BE08>
# 082930
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082930
# <pydub.audio_segment.AudioSegment object at 0x000002368687BE08>
# 082931
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082931
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB544C8>
# 082932
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\082932
# <pydub.audio_segment.AudioSegment object at 0x000002368687BC88>
# 083600
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\083600
# <pydub.audio_segment.AudioSegment object at 0x000002368687B788>
# 083612
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\083612
# <pydub.audio_segment.AudioSegment object at 0x000002368687B788>
# 083613
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\083613
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB54288>
# 084736
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\084736
# <pydub.audio_segment.AudioSegment object at 0x000002368687BCC8>
# 084768
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\084768
# <pydub.audio_segment.AudioSegment object at 0x000002368687BE08>
# 086037
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086037
# <pydub.audio_segment.AudioSegment object at 0x000002368687BE08>
# 086038
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086038
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB544C8>
# 086039
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086039
# <pydub.audio_segment.AudioSegment object at 0x000002368687BEC8>
# 086040
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086040
# <pydub.audio_segment.AudioSegment object at 0x000002368687BAC8>
# 086481
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086481
# <pydub.audio_segment.AudioSegment object at 0x000002368687BAC8>
# 086482
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086482
# <pydub.audio_segment.AudioSegment object at 0x00000236FEB544C8>
# 086483
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086483
# <pydub.audio_segment.AudioSegment object at 0x000002368687BB08>
# 086484
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086484
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE908>
# 086485
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086485
# <pydub.audio_segment.AudioSegment object at 0x000002368687BB08>
# 086486
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086486
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEAC8>
# 086487
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\086487
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7388>
# 087096
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087096
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE408>
# 087097
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087097
# <pydub.audio_segment.AudioSegment object at 0x000002368687BB08>
# 087098
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087098
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE9C8>
# 087099
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087099
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7A48>
# 087100
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087100
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7FC8>
# 087101
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087101
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7A48>
# 087102
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087102
# <pydub.audio_segment.AudioSegment object at 0x000002368687BE08>
# 087103
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087103
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7348>
# 087104
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087104
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE508>
# 087105
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087105
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7948>
# 087106
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087106
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE988>
# 087107
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087107
# <pydub.audio_segment.AudioSegment object at 0x00000236838A77C8>
# 087108
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\087108
# <pydub.audio_segment.AudioSegment object at 0x00000236838CED88>
# 090526
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\090526
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7108>
# 090527
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\090527
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEB48>
# 090529
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\090529
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7DC8>
# 090530
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\090530
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE148>
# 090616
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\090616
# <pydub.audio_segment.AudioSegment object at 0x00000236838A72C8>
# 090617
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\090617
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE3C8>
# 090618
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\090618
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7708>
# 092947
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092947
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE208>
# 092948
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092948
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7FC8>
# 092949
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092949
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7248>
# 092950
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092950
# <pydub.audio_segment.AudioSegment object at 0x00000236838A72C8>
# 092951
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092951
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEAC8>
# 092952
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092952
# <pydub.audio_segment.AudioSegment object at 0x00000236838A77C8>
# 092953
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092953
# <pydub.audio_segment.AudioSegment object at 0x00000236838A74C8>
# 092954
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092954
# <pydub.audio_segment.AudioSegment object at 0x00000236838A77C8>
# 092955
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\092955
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEEC8>
# 093915
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\093915
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7C88>
# 093917
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\093917
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE5C8>
# 093918
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\093918
# <pydub.audio_segment.AudioSegment object at 0x000002368389FAC8>
# 093919
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\093919
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7088>
# 093920
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\093920
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7088>
# 093921
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\093921
# <pydub.audio_segment.AudioSegment object at 0x000002368389F8C8>
# 094033
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\094033
# <pydub.audio_segment.AudioSegment object at 0x00000236838A71C8>
# 094034
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\094034
# <pydub.audio_segment.AudioSegment object at 0x000002368389FAC8>
# 094035
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\094035
# <pydub.audio_segment.AudioSegment object at 0x00000236838CED88>
# 094036
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\094036
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7FC8>
# 094037
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\094037
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7FC8>
# 094038
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\094038
# <pydub.audio_segment.AudioSegment object at 0x000002368389F288>
# 094039
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\094039
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7FC8>
# 095452
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\095452
# <pydub.audio_segment.AudioSegment object at 0x000002368389F388>
# 095722
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\095722
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7FC8>
# 095724
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\095724
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7FC8>
# 095725
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\095725
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE788>
# 095726
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\095726
# <pydub.audio_segment.AudioSegment object at 0x000002368389F0C8>
# 095727
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\095727
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7FC8>
# 097279
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\097279
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7088>
# 097283
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\097283
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE7C8>
# 097285
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\097285
# <pydub.audio_segment.AudioSegment object at 0x000002368389F948>
# 098235
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\098235
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7088>
# 098236
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\098236
# <pydub.audio_segment.AudioSegment object at 0x000002368389F9C8>
# 098237
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\098237
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEB88>
# 098238
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\098238
# <pydub.audio_segment.AudioSegment object at 0x000002368389F8C8>
# 103518
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\103518
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7088>
# 103519
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\103519
# <pydub.audio_segment.AudioSegment object at 0x000002368389FB48>
# 103520
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\103520
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE148>
# 103521
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\103521
# <pydub.audio_segment.AudioSegment object at 0x000002368389F8C8>
# 103522
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\103522
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7088>
# 103523
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\103523
# <pydub.audio_segment.AudioSegment object at 0x000002368389FAC8>
# 106502
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\106502
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE7C8>
# 106629
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\106629
# <pydub.audio_segment.AudioSegment object at 0x000002368389F7C8>
# 107531
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\107531
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE748>
# 107532
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\107532
# <pydub.audio_segment.AudioSegment object at 0x000002368389FB08>
# 107533
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\107533
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE448>
# 107534
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\107534
# <pydub.audio_segment.AudioSegment object at 0x000002368389FD08>
# 107535
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\107535
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE548>
# 108017
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108017
# <pydub.audio_segment.AudioSegment object at 0x000002368389FC08>
# 108018
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108018
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE188>
# 108019
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108019
# <pydub.audio_segment.AudioSegment object at 0x000002368389FCC8>
# 108020
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108020
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE208>
# 108021
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108021
# <pydub.audio_segment.AudioSegment object at 0x000002368389FB08>
# 108022
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108022
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE7C8>
# 108023
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108023
# <pydub.audio_segment.AudioSegment object at 0x00000236838A7088>
# 108024
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108024
# <pydub.audio_segment.AudioSegment object at 0x00000236838CED48>
# 108025
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108025
# <pydub.audio_segment.AudioSegment object at 0x000002368389F248>
# 108026
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108026
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEB88>
# 108027
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108027
# <pydub.audio_segment.AudioSegment object at 0x000002368389FB08>
# 108471
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108471
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE748>
# 108472
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108472
# <pydub.audio_segment.AudioSegment object at 0x000002368389F308>
# 108473
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108473
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE048>
# 108474
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108474
# <pydub.audio_segment.AudioSegment object at 0x000002368389F048>
# 108475
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108475
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE5C8>
# 108476
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108476
# <pydub.audio_segment.AudioSegment object at 0x000002368389FA08>
# 108477
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108477
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE7C8>
# 108478
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108478
# <pydub.audio_segment.AudioSegment object at 0x000002368389F948>
# 108878
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108878
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE548>
# 108879
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108879
# <pydub.audio_segment.AudioSegment object at 0x000002368389F588>
# 108880
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108880
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEE48>
# 108881
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108881
# <pydub.audio_segment.AudioSegment object at 0x000002368389FF08>
# 108882
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108882
# <pydub.audio_segment.AudioSegment object at 0x0000023683898248>
# 108883
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108883
# <pydub.audio_segment.AudioSegment object at 0x000002368389F088>
# 108884
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108884
# <pydub.audio_segment.AudioSegment object at 0x0000023683898CC8>
# 108885
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108885
# <pydub.audio_segment.AudioSegment object at 0x000002368389FC08>
# 108906
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\108906
# <pydub.audio_segment.AudioSegment object at 0x0000023683898A88>
# 109189
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\109189
# <pydub.audio_segment.AudioSegment object at 0x000002368389FBC8>
# 109191
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\109191
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEB08>
# 110647
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\110647
# <pydub.audio_segment.AudioSegment object at 0x000002368389F748>
# 110648
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\110648
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEB88>
# 110649
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\110649
# <pydub.audio_segment.AudioSegment object at 0x000002368389F308>
# 110650
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\110650
# <pydub.audio_segment.AudioSegment object at 0x00000236838CEB08>
# 110651
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\110651
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE148>
# 110652
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\110652
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE108>
# 110653
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\110653
# <pydub.audio_segment.AudioSegment object at 0x0000023683898C48>
# 110654
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\110654
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE608>
# 111015
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\111015
# <pydub.audio_segment.AudioSegment object at 0x0000023683898AC8>
# 111146
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\111146
# <pydub.audio_segment.AudioSegment object at 0x00000236838CE048>
# 111147
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\instrumental\111147
# ...
# 137716
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137716
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9388>
# 137717
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137717
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA188>
# 137719
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137719
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA488>
# 137720
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137720
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9988>
# 137721
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137721
# <pydub.audio_segment.AudioSegment object at 0x00000236831CAF88>
# 137722
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137722
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA148>
# 137723
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137723
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9448>
# 137724
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137724
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA448>
# 137725
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137725
# <pydub.audio_segment.AudioSegment object at 0x00000236831CAE48>
# 137740
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137740
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA448>
# 137935
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137935
# <pydub.audio_segment.AudioSegment object at 0x00000236831CAE48>
# 137998
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\137998
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA708>
# 138010
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138010
# <pydub.audio_segment.AudioSegment object at 0x00000236831CAE48>
# 138053
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138053
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9D88>
# 138060
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138060
# <pydub.audio_segment.AudioSegment object at 0x00000236831CAB88>
# 138061
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138061
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9408>
# 138207
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138207
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 138210
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138210
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9308>
# 138211
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138211
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA648>
# 138282
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138282
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9408>
# 138306
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138306
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA648>
# 138311
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138311
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9188>
# 138317
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138317
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA708>
# 138318
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138318
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 138319
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138319
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC848>
# 138320
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138320
# <pydub.audio_segment.AudioSegment object at 0x00000236831CAB88>
# 138351
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138351
# <pydub.audio_segment.AudioSegment object at 0x00000236831A94C8>
# 138355
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\138355
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA708>
# 139117
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\139117
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 139123
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\139123
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9408>
# 139461
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\139461
# <pydub.audio_segment.AudioSegment object at 0x00000236831BCCC8>
# 139769
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\139769
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 139770
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\139770
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9748>
# 140043
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\140043
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 140421
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\140421
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9848>
# 140576
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\140576
# <pydub.audio_segment.AudioSegment object at 0x00000236831CAC08>
# 141173
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\141173
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9608>
# 141877
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\141877
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 141878
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\141878
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9A48>
# 141894
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\141894
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC888>
# 142128
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142128
# <pydub.audio_segment.AudioSegment object at 0x00000236831A93C8>
# 142402
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142402
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC748>
# 142418
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142418
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 142511
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142511
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC7C8>
# 142563
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142563
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9DC8>
# 142947
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142947
# <pydub.audio_segment.AudioSegment object at 0x00000236831BCC88>
# 142948
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142948
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 142949
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142949
# <pydub.audio_segment.AudioSegment object at 0x00000236831BCA08>
# 142950
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\142950
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9AC8>
# 143095
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143095
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 143097
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143097
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9108>
# 143098
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143098
# <pydub.audio_segment.AudioSegment object at 0x00000236831BCF48>
# 143099
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143099
# <pydub.audio_segment.AudioSegment object at 0x00000236831A93C8>
# 143106
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143106
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9888>
# 143214
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143214
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9A48>
# 143215
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143215
# <pydub.audio_segment.AudioSegment object at 0x00000236831CA108>
# 143216
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143216
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9608>
# 143217
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143217
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC488>
# 143218
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143218
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9C48>
# 143219
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143219
# <pydub.audio_segment.AudioSegment object at 0x00000236831BCBC8>
# 143220
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143220
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9688>
# 143221
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143221
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC708>
# 143318
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143318
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9288>
# 143319
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143319
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC508>
# 143989
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143989
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9B88>
# 143995
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\143995
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC188>
# 145020
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145020
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9288>
# 145027
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145027
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9CC8>
# 145067
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145067
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9A48>
# 145068
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145068
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC988>
# 145199
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145199
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9848>
# 145241
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145241
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9288>
# 145257
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145257
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9A48>
# 145258
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145258
# <pydub.audio_segment.AudioSegment object at 0x00000236831BCF48>
# 145259
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145259
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9688>
# 145260
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145260
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC208>
# 145606
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145606
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9B88>
# 145607
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145607
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC948>
# 145608
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145608
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9888>
# 145609
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145609
# <pydub.audio_segment.AudioSegment object at 0x00000236831A97C8>
# 145610
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145610
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9FC8>
# 145780
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145780
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC948>
# 145783
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\145783
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9FC8>
# 146478
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\146478
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC888>
# 146481
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\146481
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9FC8>
# 146482
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\146482
# <pydub.audio_segment.AudioSegment object at 0x00000236831BCD08>
# 146483
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\146483
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9FC8>
# 147409
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\147409
# <pydub.audio_segment.AudioSegment object at 0x00000236831A4948>
# 147412
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\147412
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9848>
# 147413
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\147413
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC8C8>
# 147956
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\147956
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9C48>
# 148246
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\148246
# <pydub.audio_segment.AudioSegment object at 0x00000236831A4848>
# 148536
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\148536
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9C48>
# 148537
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\148537
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC608>
# 149416
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\149416
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9FC8>
# 149417
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\149417
# <pydub.audio_segment.AudioSegment object at 0x00000236831A9C48>
# 149452
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\149452
# <pydub.audio_segment.AudioSegment object at 0x00000236831BC888>
# 149488
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\149488
# <pydub.audio_segment.AudioSegment object at 0x00000236831BCDC8>
# 149523
# C:\Users\alvar\github\gitTfgPy\TFGNotebooks\Datasets\fma\small_dataset_reduced\rock\149523

# %%
from pathlib import Path
from os import remove
import librosa


"""
Clean audio files of possible empty files
"""

def read_and_clean_empty_audios(path):
    audio = librosa.load(path, 44100)[0]
    if audio.size == 0:
        remove(path)
        print(path, "removed")

for p in Path().glob('Datasets/fma/small_dataset_reduced/hiphop/*'):
    read_and_clean_empty_audios(p)

for p in Path().glob('Datasets/fma/small_dataset_reduced/instrumental/*'):
    read_and_clean_empty_audios(p)

for p in Path().glob('Datasets/fma/small_dataset_reduced/international/*'):
    read_and_clean_empty_audios(p)
    
for p in Path().glob('Datasets/fma/small_dataset_reduced/pop/*'):
    read_and_clean_empty_audios(p)
    
for p in Path().glob('Datasets/fma/small_dataset_reduced/rock/*'):
    read_and_clean_empty_audios(p)
# Out:
# Datasets\fma\small_dataset_reduced\hiphop\098565 removed
# Datasets\fma\small_dataset_reduced\hiphop\098567 removed
# Datasets\fma\small_dataset_reduced\hiphop\098569 removed
